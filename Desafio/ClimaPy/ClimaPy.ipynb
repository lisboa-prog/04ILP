# %% [markdown]
# # Weather.Py - Ferramenta de Análise de Clima em Python
# ----
#
# #### Gerador aleatório de cidades e análise meteorológica por latitudes

# %%
# Dependências e configuração


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from scipy.stats import linregress
from datetime import datetime

# Importação da Chave API( API key)
# from api_keys import weather_api_key
# Professor, esta chave API é temporaria depois eu irei apagar
weather_api_key = "05b11185be5856c9012fcfbc2f94e099"

# Cidade incorporada para determinar a cidade com base na latitude e longitude
# instale a partir da linha de comando antes de abrir o notebook jupyter como 'pip install citipy'
from citipy import citipy

# Arquivo de saída (CSV)
output_data_file = "output_data/cities.csv"

# Faixa de latitudes e longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Gerar lista de cidades

# %%
# Lista de retenção de lat_lngs e cidades
lat_lngs = []
cities = []

# Crie um conjunto de combinações aleatórias de lat e lng
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)

lat_lngs = zip(lats, lngs)

# Identifique a cidade mais próxima para cada combinação de lat e lng
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # Se a cidade for única, adicione-a à nossa lista de cidades
    if city not in cities:
        cities.append(city)

# Imprima a contagem de cidades para confirmar a contagem suficiente
len(cities)
# Out:
# 607

# %% [markdown]
# ### Realizar chamadas de API
# * Execute uma verificação meteorológica em cada cidade usando uma série de chamadas de API sucessivas.
# * Inclua um registro impresso de cada cidade à medida que ela for processada (com o número e o nome da cidade).

# %%
# crie url para consulta com unidades imperiais e cidade no final
# url from https://openweathermap.org/appid
url = "http://api.openweathermap.org/data/2.5/weather?id=524901"
unit = "imperial"
query_url = f"{url}&appid={weather_api_key}&units={unit}&q="

# Lists for results
lat = []
lon = []
foundCities = []
temp = []
humidity = []
cloudiness = []
windSpeed = []
date = []
country = []

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windSpeed.append(response["wind"]["speed"])
        date.append(response["dt"])
        country.append(response["sys"]["country"])
        foundCities.append(city)
        print(f"City processed: {city}")
    except:
        print(f"City NOT found: {city}")
# Out:
# City processed: kununurra
# City processed: grytviken
# City processed: port-aux-francais
# City processed: petropavlovsk-kamchatsky
# City processed: akim swedru
# City processed: ushuaia
# City processed: puerto ayora
# City processed: tolanaro
# City processed: dolinsk
# City processed: winneba
# City processed: salazie
# City processed: waitangi
# City processed: daruvar
# City processed: yellowknife
# City processed: mahajanga
# City processed: isafjordur
# City processed: stanley
# City processed: port sudan
# City processed: anadyr
# City processed: ilulissat
# City processed: jamestown
# City processed: international falls
# City processed: ruidoso
# City processed: sequim
# City processed: mili
# City processed: chilaw
# City processed: vila franca do campo
# City processed: west island
# City processed: puerto natales
# City processed: moraleja
# City NOT found: alipur duar
# City processed: wynyard
# City processed: axim
# City processed: papatowai
# City processed: adamstown
# City processed: edinburgh of the seven seas
# City processed: afaahiti
# City processed: tiksi
# City processed: margaret river
# City processed: haiku-pauwela
# City processed: klyuchi
# City processed: albany
# City processed: blackmans bay
# City processed: saipan
# City processed: altagracia de orituco
# City NOT found: taiohae
# City processed: namtsy
# City processed: udachny
# City processed: bulungu
# City processed: cuajinicuilapa
# City processed: larkird
# City processed: salamanca
# City processed: belyy yar
# City processed: lerwick
# City processed: olonkinbyen
# City processed: georgetown
# City processed: miles city
# City processed: avarua
# City processed: alice springs
# City processed: east london
# City processed: cole harbour
# City processed: nemuro
# City processed: stephenville
# City processed: yarmouth
# City processed: hilo
# City NOT found: kulia village
# City processed: hamilton
# City processed: biarritz
# City processed: zhosaly
# City processed: college
# City processed: iskateley
# City processed: longyearbyen
# City processed: tomatlan
# City processed: bilibino
# City NOT found: gueltat zemmour
# City processed: yangambi
# City NOT found: kattaqo'rg'on shahri
# City processed: port mathurin
# City processed: alaghsas
# City NOT found: san antonio del estrecho
# City processed: hermanus
# City NOT found: kazalinsk
# City processed: fort bragg
# City processed: ancud
# City processed: kosti
# City processed: punta arenas
# City processed: nampula
# City processed: pisco
# City processed: lihue
# City processed: kingston
# City processed: arraial do cabo
# City processed: verkhnevilyuysk
# City processed: kodinsk
# City NOT found: toga village
# City processed: callao
# City processed: choele choel
# City processed: bethel
# City processed: caluula
# City processed: al bawiti
# City processed: aasiaat
# City processed: whitehorse
# City processed: bossangoa
# City processed: lucas
# City processed: badger
# City NOT found: kultali
# City processed: utrik
# City NOT found: manatutu
# City processed: susuman
# City processed: iqaluit
# City processed: chui
# City processed: kundiawa
# City processed: trindade
# City processed: masaurhi buzurg
# City processed: sitka
# City processed: kruisfontein
# City processed: bam
# City processed: albu kamal
# City processed: les cayes
# City processed: praia da vitoria
# City processed: tanjungtiram
# City processed: nar'yan-mar
# City processed: piranhas
# City processed: lagoa
# City processed: kombolcha
# City processed: hawaiian paradise park
# City processed: maceio
# City NOT found: fuvahmulah
# City processed: bom jesus da lapa
# City processed: holualoa
# City processed: kill devil hills
# City processed: svetlyy
# City processed: salinas
# City processed: hoopstad
# City processed: hasaki
# City processed: bredasdorp
# City processed: gadzhiyevo
# City processed: sao tome
# City processed: constantia
# City processed: bamboo flat
# City processed: sisimiut
# City processed: carnarvon
# City processed: loboc
# City processed: chany
# City processed: ulsteinvik
# City processed: starobin
# City processed: atafu village
# City processed: carlos chagas
# City processed: price
# City processed: la passe
# City processed: tazacorte
# City processed: qaqortoq
# City processed: northam
# City processed: luderitz
# City processed: lincoln
# City processed: rio grande
# City processed: aldan
# City processed: lockwood
# City processed: natal
# City NOT found: 'ohonua
# City processed: tazovsky
# City processed: sirte
# City processed: laguna
# City processed: kone
# City processed: tangalle
# City processed: portland
# City processed: prairie du chien
# City processed: fale old settlement
# City processed: vievis
# City processed: ceres
# City processed: talnakh
# City processed: prince rupert
# City processed: christchurch
# City NOT found: alotau
# City processed: bikenibeu village
# City processed: bubaque
# City processed: soe
# City processed: whitby
# City processed: vilyuchinsk
# City processed: mount isa
# City processed: dawson creek
# City processed: itaituba
# City processed: tralee
# City processed: vadso
# City processed: invercargill
# City processed: el tigre
# City processed: kapa'a
# City processed: qamdo
# City processed: codrington
# City processed: letlhakeng
# City processed: micheweni
# City processed: adamovka
# City processed: ghat
# City processed: feijo
# City processed: lompoc
# City processed: hithadhoo
# City processed: mermoz boabab
# City processed: nerchinsk
# City processed: sandnessjoen
# City processed: st. john's
# City processed: luis correia
# City processed: tibanbang
# City processed: dazuocun
# City processed: kavaratti
# City NOT found: bargara
# City processed: ribeira grande
# City processed: barra de santo antonio
# City processed: marsabit
# City processed: happy valley-goose bay
# City processed: conde
# City processed: hobyo
# City processed: palikir - national government center
# City processed: lisakovsk
# City processed: palmer
# City processed: kermit
# City processed: lospalos
# City processed: egilsstadir
# City processed: ouargaye
# City processed: ust-nera
# City processed: colonia
# City processed: lebu
# City processed: marquette
# City processed: xichang
# City processed: new norfolk
# City processed: wanning
# City processed: morehead city
# City processed: coquimbo
# City processed: moose jaw
# City processed: kayangel
# City processed: peace river
# City processed: viedma
# City processed: prado
# City processed: chul'man
# City processed: ola
# City processed: fortuna
# City processed: mil'kovo
# City processed: namibe
# City processed: yanam
# City processed: port alfred
# City processed: bijie
# City processed: ribeira brava
# City processed: al jawf
# City processed: chibougamau
# City processed: paita
# City processed: santa elena de uairen
# City processed: thompson
# City processed: fort wellington
# City processed: chernushka
# City processed: amos
# City processed: shalqar
# City processed: tamanrasset
# City processed: mugia
# City processed: kuta
# City processed: humberto de campos
# City processed: ocean city
# City processed: sumenep
# City processed: enewetak
# City processed: morgan city
# City processed: dongyang
# City processed: kamaishi
# City processed: sidi khaled
# City processed: san luis
# City processed: wailua homesteads
# City processed: klaksvik
# City processed: antonio enes
# City processed: kapuskasing
# City NOT found: tranovaho
# City processed: margate
# City processed: tobruk
# City processed: duong dong
# City processed: gizo
# City processed: kyaikkami
# City NOT found: rio turbio
# City processed: trinity beach
# City processed: mercedes
# City processed: chonchi
# City NOT found: zhetybay
# City processed: ugoofaaru
# City processed: gudauta
# City processed: road town
# City processed: okha
# City processed: jian'ou
# City processed: usogorsk
# City processed: uturoa
# City processed: santa terezinha
# City processed: nuku'alofa
# City processed: basoko
# City processed: talara
# City processed: newman
# City processed: pacific grove
# City processed: tsiombe
# City processed: magistral'nyy
# City processed: sao vicente
# City processed: el asintal
# City processed: greymouth
# City processed: castillos
# City processed: copiapo
# City NOT found: muzayri'
# City processed: haapsalu
# City processed: thinadhoo
# City processed: bemidji
# City processed: port elizabeth
# City processed: shimoda
# City processed: teguise
# City processed: bibai
# City processed: ta`u
# City processed: guerrero negro
# City processed: saint-pierre
# City processed: vorgashor
# City processed: huarmey
# City NOT found: cumaribo
# City processed: andahuaylas
# City processed: warman
# City processed: tual
# City processed: hoopeston
# City processed: selfoss
# City processed: el paso
# City NOT found: posto da mata
# City processed: monte di procida
# City processed: touros
# City processed: nuevo ideal
# City processed: keflavik
# City processed: nuuk
# City processed: porto novo
# City processed: kolonia
# City processed: port moresby
# City processed: paoua
# City processed: el granada
# City processed: ust-tsilma
# City NOT found: hayma'
# City processed: metlili chaamba
# City processed: kristiansund
# City processed: tindouf
# City processed: howrah
# City processed: grand falls-windsor
# City processed: ebon
# City processed: kasongo-lunda
# City processed: nyaunglebin
# City processed: dire dawa
# City processed: tres arroyos
# City processed: sungai raya
# City processed: ndele
# City processed: flying fish cove
# City processed: nueva gerona
# City processed: puerto baquerizo moreno
# City processed: columbia falls
# City processed: cafayate
# City processed: al bardiyah
# City processed: benghazi
# City processed: port augusta
# City processed: general roca
# City processed: hammerfest
# City processed: natchitoches
# City processed: el-tor
# City processed: kisangani
# City processed: winston
# City processed: saldanha
# City processed: sebastopol
# City processed: leua
# City processed: sur
# City processed: bodo
# City processed: fort stockton
# City processed: gioia tauro
# City processed: mandalgovi
# City processed: kidal
# City processed: sault ste. marie
# City processed: khorugh
# City processed: tura
# City processed: fairfield
# City processed: boa vista
# City processed: le vauclin
# City processed: crane
# City processed: morris
# City processed: redencao
# City processed: darwin
# City processed: kudahuvadhoo
# City processed: kachug
# City NOT found: al-`ula
# City processed: katsuura
# City processed: kailua-kona
# City processed: mogocha
# City processed: viljandi
# City processed: andergrove
# City processed: nova sintra
# City processed: mala
# City processed: ovalle
# City processed: constitucion
# City processed: raduzhnyy
# City processed: belmonte
# City processed: mendes
# City processed: kuvshinovo
# City processed: gourdon
# City processed: chetwayi
# City processed: richards bay
# City processed: ormara
# City processed: tucurui
# City processed: mejit
# City processed: mersa matruh
# City processed: bengkulu
# City processed: port lincoln
# City processed: balkanabat
# City processed: kerikeri
# City processed: taunggyi
# City processed: caister-on-sea
# City processed: dodge city
# City processed: banes
# City processed: severo-yeniseyskiy
# City processed: meraux
# City processed: at taj
# City processed: santo domingo de la calzada
# City processed: cidreira
# City processed: al kharijah
# City processed: madison
# City processed: aketi
# City processed: sinop
# City processed: dolores
# City processed: sosnovo-ozerskoye
# City processed: magadan
# City processed: berdigestyakh
# City processed: mar del plata
# City processed: inhambane
# City processed: miri
# City processed: tayoltita
# City processed: phang nga
# City processed: murun-kuren
# City processed: agryz
# City processed: antalaha
# City processed: massawa
# City processed: batang
# City processed: choyr
# City processed: papao
# City processed: yuzhno-kurilsk
# City processed: kaifeng
# City processed: kourou
# City NOT found: tsiolkovskiy
# City processed: vila velha
# City processed: peniche
# City processed: bad durrenberg
# City processed: north bay
# City processed: nizhnevartovsk
# City processed: nagqu
# City processed: arteche
# City processed: novodvinsk
# City processed: labuan
# City processed: beyneu
# City processed: kodiak
# City processed: sainyabuli
# City processed: upington
# City processed: gornopravdinsk
# City processed: rio gallegos
# City processed: esik
# City processed: aki
# City processed: owo
# City processed: gamba
# City processed: plettenberg bay
# City processed: arvika
# City processed: the pas
# City processed: aras-asan
# City processed: barclayville
# City NOT found: governor's harbour
# City processed: dudinka
# City processed: cabo san lucas
# City processed: kyabe
# City processed: khvoynaya
# City processed: tegueste
# City processed: khandyga
# City processed: kudat
# City processed: la ronge
# City processed: alesund
# City processed: faya-largeau
# City processed: kenai
# City processed: catemaco
# City processed: anan
# City processed: kralendijk
# City processed: krasyliv
# City processed: pierre
# City processed: adam
# City processed: muravlenko
# City processed: alofi
# City processed: malabar
# City processed: jiuquan
# City processed: bure
# City processed: barra da estiva
# City processed: bordj bou arreridj
# City processed: dwarka
# City processed: jumla
# City processed: khachrod
# City processed: gwangju
# City processed: xilin hot
# City processed: massenya
# City processed: praia
# City processed: coronel dorrego
# City processed: albufeira
# City processed: al artawiyah
# City processed: pudozh
# City NOT found: cargados carajos
# City processed: padangsidempuan
# City processed: terrace
# City processed: ketchikan
# City processed: silver city
# City processed: akureyri
# City processed: imbituba
# City processed: colby
# City processed: zyryanovsk
# City processed: balvi
# City processed: labrador city
# City processed: aripuana
# City processed: lysekil
# City processed: midvagur
# City processed: swift current
# City processed: nazare
# City processed: bengbu
# City processed: rongelap
# City processed: sangueya
# City processed: qarqaraly
# City processed: rawson
# City processed: villamontes
# City processed: karungdong
# City processed: myeik
# City processed: elliot lake
# City processed: cockburn town
# City processed: griffith
# City processed: mwene-ditu
# City processed: brookings
# City processed: sorong
# City processed: baise city
# City processed: geraldton
# City processed: sukumo
# City processed: joshua tree
# City processed: madang
# City processed: salekhard
# City processed: nyurba
# City processed: nianzishan
# City processed: ambon
# City processed: cynthiana
# City processed: sabang
# City NOT found: devinuwara
# City NOT found: port-de-paix
# City processed: san luis de la loma
# City processed: nema
# City NOT found: saratamata
# City processed: kencong
# City processed: iskitim
# City processed: fredericton
# City processed: ardestan
# City processed: haimen
# City NOT found: cable beach
# City processed: bathsheba
# City processed: birjand
# City processed: hawkesbury
# City processed: tapa
# City processed: carutapera
# City processed: cooper's town
# City processed: playa del ingles
# City processed: sao joao da barra
# City processed: kyren
# City processed: gamay
# City processed: pariaman
# City processed: barabai
# City processed: karratha
# City processed: shakawe
# City processed: kurumkan
# City processed: pemangkat
# City processed: kavieng
# City processed: qom
# City processed: novotroitskaya
# City processed: guiuan
# City processed: al bayda'
# City processed: insar
# City processed: laguna de perlas
# City processed: vanimo
# City processed: as sulayyil
# City processed: antofagasta
# City processed: jayapura
# City processed: egersund
# City processed: benguela
# City processed: kuraymah
# City processed: bratca
# City processed: green river
# City processed: kalush
# City processed: valparaiso
# City processed: shengli
# City processed: san bonifacio
# City processed: mossel bay
# City processed: fu'an
# City processed: senanga
# City processed: ujae
# City processed: remire-montjoly
# City processed: gaspe
# City processed: araripe
# City NOT found: villa unida
# City processed: mishan
# City processed: zalingei
# City processed: sunbury
# City processed: i-n-salah
# City processed: tommot
# City processed: kajuru
# City processed: rehoboth
# City processed: shiqian
# City processed: vorkuta
# City processed: makhambet
# City NOT found: puerto san carlos
# City processed: attapeu
# City processed: tirat karmel
# City processed: almenara
# City processed: le port
# City processed: acarau
# City processed: ishigaki

# %% [markdown]
# ### Converter dados brutos em DataFrame
# * Exporte os dados da cidade para um .csv.
# * Exibir o DataFrame

# %%
Weather_DF = pd.DataFrame({"City": foundCities,
                           "Country": country,
                           "Temperature": temp,
                           "Humidity": humidity,
                           "Cloudiness": cloudiness,
                           "Windspeed":windSpeed,
                           "Latitude": lat,
                           "Longitude": lon,
                           "Date": date
                          })

# %%
# Caminho da área de trabalho do Windows
Weather_DF.to_csv(
    r"D:/David/Backup/2023/PosGraduacao/Modulo1/04ILP/Desafio/output_data/Cities.csv",
    index=False,
)
# Caminho da área de trabalho do Macbook (caso queira testar no seu Notebook profesor)
# Weather_DF.to_csv(r'D:/David/Backup/2023/PosGraduacao/Modulo1/04ILP/Desafio/output_data/Cities.csv', index = False)
Weather_DF
# Out:
#                          City Country  Temperature  Humidity  Cloudiness  \
# 0                   kununurra      AU        84.18        70          17
# 1                   grytviken      GS        31.03        77          10
# 2           port-aux-francais      TF        38.97        82          42
# 3    petropavlovsk-kamchatsky      RU        34.45        63         100
# 4                 akim swedru      GH        73.63        97          66
# ..                        ...     ...          ...       ...         ...
# 571              tirat karmel      IL        74.68        73          25
# 572                  almenara      BR        76.41        75          98
# 573                   le port      RE        77.00        90         100
# 574                    acarau      BR        80.13        80          42
# 575                  ishigaki      JP        78.93        83          40
#
#      Windspeed  Latitude  Longitude        Date
# 0         0.00  -15.7667   128.7333  1698881541
# 1         9.53  -54.2811   -36.5092  1698881541
# 2        30.74  -49.3500    70.2167  1698881542
# 3         6.71   53.0452   158.6483  1698881542
# 4         2.21    5.8938    -1.0164  1698881543
# ..         ...       ...        ...         ...
# 571      14.34   32.7617    34.9719  1698881886
# 572       2.93  -16.1836   -40.6944  1698881886
# 573      19.42  -20.9373    55.2919  1698881887
# 574      13.94   -2.8856   -40.1200  1698881887
# 575      13.80   24.3448   124.1572  1698881888
#
# [576 rows x 9 columns]

# %% [markdown]
# ## Inspecione os dados e remova as cidades onde a umidade é > 100%.
# ----
# Pule esta etapa se não houver cidades com umidade > 100%.

# %%
badHumidityDF = Weather_DF[(Weather_DF['Humidity'] > 100)]
badHumidityDF
# Out:
# Empty DataFrame
# Columns: [City, Country, Temperature, Humidity, Cloudiness, Windspeed, Latitude, Longitude, Date]
# Index: []

# %%
#  Obtenha os índices das cidades que apresentam umidade superior a 100%.
badHumidityDF.index
# Out:
# Index([], dtype='int64')

# %%
# Faça um novo DataFrame igual aos dados da cidade para eliminar todos os valores discrepantes de umidade por índice.
# Passar "inplace=False" fará uma cópia do DataFrame city_data, que chamamos de "clean_city_data".

clean_city_data = Weather_DF.join(badHumidityDF, how="outer")

clean_city_data = Weather_DF.merge(badHumidityDF, on=index, inplace=False).query(
    "index!=index"
)

# %%
# Extraia campos relevantes do quadro de dados
City_Data = Weather_DF[
    [
        "City",
        "Country",
        "Latitude",
        "Temperature",
        "Humidity",
        "Cloudiness",
        "Windspeed",
        "Date",
    ]
]

# Exporte City_Data para um csv
# Caminho do Windows
City_Data.to_csv(
    r"D:/David/Backup/2023/PosGraduacao/Modulo1/04ILP/Desafio/output_data/City_Data.csv",
    index=False,
)
# Caminho do Macbook
# City_Data.to_csv(r'D:/David/Backup/2023/PosGraduacao/Modulo1/04ILP/Desafio/output_data/City_Data.csv', index = False)
City_Data.head()
# Out:
#                        City Country  Latitude  Temperature  Humidity  \
# 0                 kununurra      AU  -15.7667        84.18        70
# 1                 grytviken      GS  -54.2811        31.03        77
# 2         port-aux-francais      TF  -49.3500        38.97        82
# 3  petropavlovsk-kamchatsky      RU   53.0452        34.45        63
# 4               akim swedru      GH    5.8938        73.63        97
#
#    Cloudiness  Windspeed        Date
# 0          17       0.00  1698881541
# 1          10       9.53  1698881541
# 2          42      30.74  1698881542
# 3         100       6.71  1698881542
# 4          66       2.21  1698881543

# %% [markdown]
# ## Plotando os dados
# * Use rotulagem adequada dos gráficos usando títulos de gráficos (incluindo data de análise) e rótulos de eixos.
# * Salve as figuras plotadas como .png.

# %% [markdown]
# ## Gráfico de latitude vs. temperatura

# %%
# formate a data máxima no conjunto de dados como "runDate" para títulos de gráficos
endRunDate = City_Data["Date"].max()
runDate = datetime.utcfromtimestamp(endRunDate).strftime("%Y-%m-%d")

# definir dados para plota
x = City_Data["Latitude"]
y = City_Data["Temperature"]
plt.scatter(x, y)
# adicionar linhas de grade
plt.grid()
# adicione títulos e rótulos de eixo
plt.title(f"Latitude vs Temperature on {runDate}")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
# exportar como png
plt.savefig(f"../output_data/Latitude vs Temperature on {runDate}.png")
# mostra plot!
plt.show()

# %% [markdown]
# ### Análise do gráfico de dispersão de latitude x temperatura
#
# O gráfico de dispersão mapeia a temperatura das cidades em relação à sua latitude. Cidades selecionadas aleatoriamente.
# O arco do gráfico de dispersão mostra a temperatura aumentando perto do equador (Latitude 0) e diminuindo mais longe. Dada a data de execução de junho de 2020, o gráfico também distorce temperaturas mais elevadas à direita do equador devido ao verão no hemisfério norte.

# %% [markdown]
# ## Gráfico de Latitude vs. Umidade

# %%
# definir dados para plotar; retenha a latitude do gráfico anterior como "x"
h = City_Data["Humidity"]
plt.scatter(x, h)
plt.title(f"Latitude vs Humidity on {runDate}")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig(f"../output_data/Latitude vs Humidity on {runDate}.png")
plt.show()

# %% [markdown]
# ### Informações sobre o gráfico de dispersão de latitude x umidade
#
# O gráfico de dispersão mapeia a umidade das cidades em relação à sua latitude. Cidades selecionadas aleatoriamente.
#
# O resultado não revela nenhuma correlação particular entre umidade e latitude.

# %% [markdown]
# ## Gráfico de Latitude vs. Nebulosidade

# %%
c = City_Data["Cloudiness"]
plt.scatter(x,c)
plt.title(f"Latitude vs Cloudiness on {runDate}")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig(f'../output_data/Latitude vs Cloudiness on {runDate}.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Informações sobre o Gráfico de Dispersão de Latitude x Nebulosidade
#
# O gráfico de dispersão mapeia a porcentagem de nebulosidade das cidades em relação à sua latitude. Cidades selecionadas aleatoriamente.
#
# O resultado não revela nenhuma correlação particular entre nebulosidade e latitude. No entanto, pode haver uma ligeira tendência para percentagens arredondadas de nebulosidade, dados os agrupamentos próximos de cada linha de 10s (ex: 40% de nebulosidade).

# %% [markdown]
# ## Gráfico Latitude vs. Velocidade do Vento

# %%
ws = City_Data["Windspeed"]
print (ws)
plt.scatter(x,ws)
plt.title(f"Latitude vs Windspeed on {runDate}")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Windspeed (mph)")
plt.savefig(f'../output_data/Latitude vs Windspeed on {runDate}.png')
plt.show()
# Out:
# 0       0.00
# 1       9.53
# 2      30.74
# 3       6.71
# 4       2.21
#        ...
# 571    14.34
# 572     2.93
# 573    19.42
# 574    13.94
# 575    13.80
# Name: Windspeed, Length: 576, dtype: float64

# %% [markdown]
# ### Informações sobre o gráfico de dispersão de latitude e velocidade do vento
#
# O gráfico de dispersão mapeia a velocidade do vento das cidades em relação à sua latitude. Cidades selecionadas aleatoriamente.
#
# O resultado não revela nenhuma correlação particular entre a velocidade do vento e a latitude.

# %% [markdown]
# ## Regressão linear

# %%
# Função para criar gráficos de regressão linear

# função a ser chamada é "linearRegression"
# variáveis ​​são
# x_values: primeiro conjunto de data
# y_values: segundo conjunto de data
# regEQplotX: onde a equação de regressão linear aparece na linha plot x do gráfico
# regEQplotY: onde a equação de regressão linear aparece na linha y do gráfico
# y_label: o rótulo do eixo y do gráfico (o rótulo x é sempre Latitude)


def linearRegression(x_values, y_values, regEQplotX, regEQplotY, y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    print(f"The r-square is {rvalue}")
    print(line_eq)
    plt.annotate(line_eq, (regEQplotX, regEQplotY), fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel(f"{y_label}")
    plt.grid()


x = Weather_DF["Latitude"]
y = City_Data["Humidity"]

linearRegression(x, y, 0, 40, "reg")
# Out:
# The r-square is 0.049490173605055886
# y = 0.03x + 71.68

# %%
# Criar DataFrames do Hemisfério Norte e Sul
# pull loc acima e abaixo do equador; observe que todas as cidades diretamente no equador (ou seja, latitude = 0) são excluídas

Northern_DF = Weather_DF.loc[Weather_DF["Latitude"] > 0]

Southern_DF = Weather_DF.loc[Weather_DF["Latitude"] < 0]

# %% [markdown]
# #### Hemisfério Norte - Regressão Linear de Temperatura Máxima vs. Latitude

# %%
# defina os conjuntos de dados para comparar
x_values = Northern_DF["Latitude"]
y_values = Northern_DF["Temperature"]
# tweak onde a equação aparece no gráfico
regEQplotX = 0
regEQplotY = 40
# titulo o eixo y
y_label = "Temperature (F)"
# Coloca o titulo
plt.title(f"Latitude do Hemisfério Norte vs Temperatura em {runDate}")
# execute a função com todas as 5 variáveis
linearRegression(x_values, y_values, regEQplotX, regEQplotY, y_label)
# save como png na pasta output_data folder
plt.savefig(
    f"../output_data/Latitude do Hemisfério Norte vs Temperatura em {runDate}.png"
)
plt.show()
# Out:
# The r-square is -0.8519449121381371
# y = -1.03x + 91.99

# %% [markdown]
# #### Hemisfério Sul - Temperatura Máxima vs. Regressão Linear de Latitude

# %%
x_values = Southern_DF["Latitude"]
y_values = Southern_DF["Temperature"]
regEQplotX = -25
regEQplotY = 40
y_label = "Temperature (F)"
plt.title(f"Latitude do hemisfério sul vs temperatura relativa em {runDate}")
linearRegression(x_values, y_values, regEQplotX, regEQplotY, y_label)
plt.savefig(
    f"../output_data/Latitude do hemisfério sul vs temperatura relativa em  {runDate}.png"
)
plt.show()
# Out:
# The r-square is 0.8046925308428524
# y = 0.69x + 84.73

# %% [markdown]
# ### Latitude Norte/Sul vs TEMPERATURA Análise de regressão linear
#
# O gráfico de dispersão mapeia a temperatura das cidades do Norte e do Sul em relação à sua latitude. Cidades selecionadas aleatoriamente.
#
# O resultado revela uma forte correlação entre a distância da temperatura do equador. Quanto mais próximo do equador, maior será a temperatura.

# %% [markdown]
# #### Hemisfério Norte - Umidade (%) vs. Regressão Linear de Latitude

# %%
x_values = Northern_DF["Latitude"]
y_values = Northern_DF["Humidity"]
regEQplotX = 45
regEQplotY = 15
y_label = "Umidade (%)"
plt.title(f"Latitude do Hemisfério Norte vs Umidade relativa em {runDate}")
linearRegression(x_values, y_values, regEQplotX, regEQplotY, y_label)
plt.savefig(
    f"../output_data/Latitude do Hemisfério Norte vs Umidade relativa em {runDate}.png"
)
plt.show()
# Out:
# The r-square is 0.08591035867577661
# y = 0.09x + 68.78

# %% [markdown]
# #### Hemisfério Sul - Umidade (%) vs. Regressão Linear de Latitude

# %%
x_values = Southern_DF["Latitude"]
y_values = Southern_DF["Humidity"]
regEQplotX = -55
regEQplotY = 35
y_label = "Humidity (%)"
plt.title(f"Latitude do Hemisfério Sul vs Umidade relativa em {runDate}")
linearRegression(x_values, y_values, regEQplotX, regEQplotY, y_label)
plt.savefig(
    f"../output_data/Latitude do Hemisfério Sul vs Umidade relativa em {runDate}.png"
)
plt.show()
# Out:
# The r-square is 0.18502007224208153
# y = 0.23x + 77.75

# %% [markdown]
# ### Latitude Norte/Sul vs HUMIDADE Análise de regressão linear
#
# O gráfico de dispersão mapeia a umidade das cidades do Norte e do Sul em relação à sua latitude. Cidades selecionadas aleatoriamente.
#
# O resultado não revela nenhuma correlação entre latitude e umidade.

# %% [markdown]
# #### Hemisfério Norte - Nebulosidade (%) vs. Regressão Linear de Latitude

# %%
x_values = Northern_DF["Latitude"]
y_values = Northern_DF["Cloudiness"]
regEQplotX = 0
regEQplotY = 25
y_label = "Cloudiness (%)"
plt.title(f"Latitude do Hemisfério Norte vs Nebulosidade relativa em {runDate}")
linearRegression(x_values, y_values, regEQplotX, regEQplotY, y_label)
plt.savefig(
    f"../output_data/Latitude do Hemisfério Norte vs Nebulosidade relativa em {runDate}.png"
)
plt.show()
# Out:
# The r-square is 0.12740755681281477
# y = 0.25x + 49.23

# %% [markdown]
# #### Hemisfério Sul - Nebulosidade (%) vs. Regressão Linear de Latitude

# %%
x_values = Southern_DF["Latitude"]
y_values = Southern_DF["Cloudiness"]
regEQplotX = -55
regEQplotY = 60
y_label = "Nebulosidade (%)"
plt.title(f"Latitude do Hemisfério Sul vs Nebulosidade relativa em {runDate}")
linearRegression(x_values, y_values, regEQplotX, regEQplotY, y_label)
plt.savefig(
    f"../output_data/Latitude do Hemisfério Sul vs Nebulosidade relativa em {runDate}.png"
)
plt.show()
# Out:
# The r-square is 0.04020333025013803
# y = 0.1x + 65.45

# %% [markdown]
# ### Latitude Norte/Sul vs Nevulosidade Análise de regressão linear
#
# O gráfico de dispersão mapeia a nebulosidade das cidades do Norte e do Sul em relação à sua latitude. Cidades selecionadas aleatoriamente.
#
# O resultado não revela nenhuma correlação entre latitude e nebulosidade.

# %% [markdown]
# #### Hemisfério Norte - Velocidade do Vento (mph) vs. Regressão Linear de Latitude

# %%
x_values = Northern_DF["Latitude"]
y_values = Northern_DF["Windspeed"]
regEQplotX = 35
regEQplotY = 25
y_label = "Velocidade do Vento (MPH)"
plt.title(f"Latitude do Hemisfério Norte vs Velocidade do Vento ativada em {runDate}")
linearRegression(x_values, y_values, regEQplotX, regEQplotY, y_label)
plt.savefig(
    f"../output_data/Latitude do Hemisfério Norte vs Velocidade do Vento ativada em {runDate}.png"
)
plt.show()
# Out:
# The r-square is 0.21233482316052538
# y = 0.07x + 5.49

# %% [markdown]
# #### Hemisfério Sul - Velocidade do Vento (mph) vs. Regressão Linear de Latitude

# %%
x_values = Southern_DF["Latitude"]
y_values = Southern_DF["Windspeed"]
regEQplotX = -50
regEQplotY = 25
y_label = "Velocidade do Vento (MPH)"
plt.title(f"Latitude do Hemisfério Sul vs Velocidade do Vento ativada em {runDate}")
linearRegression(x_values, y_values, regEQplotX, regEQplotY, y_label)
plt.savefig(
    f"../output_data/Latitude do Hemisfério Sul vs Velocidade do Vento ativada em {runDate}.png"
)
plt.show()
# Out:
# The r-square is -0.26235093459536163
# y = -0.11x + 6.2
